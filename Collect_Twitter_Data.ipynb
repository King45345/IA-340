# %% [markdown]
# # Collect_Twitter_Data

# %% [markdown]
# ## Install Python libraries

# %% [markdown]
# We need the [pymongo](https://pypi.org/project/pymongo/) to manage the MongoDB database, and [tweepy](https://www.tweepy.org/) to call the Twitter APIs.

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.4 MB/s  0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# Successfully installed dnspython-2.8.0 pymongo-4.15.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting oauthlib<4,>=3.2.0 (from tweepy)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tweepy) (2.32.5)
# Collecting requests-oauthlib<3,>=1.2.0 (from tweepy)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (2025.10.5)
# Downloading tweepy-4.16.0-py3-none-any.whl (98 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [tweepy]
# Successfully installed oauthlib-3.3.1 requests-oauthlib-2.0.0 tweepy-4.16.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Secret Manager Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Import Python Libraries and Credentials

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy

bearer_token   = get_secret('twitter_api')['bearer_token']

mongodb_connect = get_secret('mongodb')['connection_string']

# %% [markdown]
# ## Connect to the MongoDB cluster

# %% [markdown]
# We will create a database named 'demo' and a collection named 'tweet_collection' in your MongoDB database.

# %%
mongo_client = MongoClient(mongodb_connect)
db = mongo_client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("tweet.id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'tweet.id_1'

# %% [markdown]
# ## Use the API to collect tweets

# %% [markdown]
# For more about Twitter API 2.0 query operators, please check [Search Tweets](https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query)

# %%
query = 'election'  #query tweets contain the word of 'election'

# %% [markdown]
# Insert the collected Tweets into the MongoDB database. You can set a different max_result, but the max tweets we can collect is 100.

# %%
tweet_client = tweepy.Client(bearer_token)

tweets = tweet_client.search_recent_tweets(query=query, max_results=100,
                                    expansions=['author_id'], 
                                    tweet_fields = ['created_at','entities','lang','public_metrics','geo'],
                                    user_fields = ['id', 'location','name', 'public_metrics','username'])

next_token = tweets.meta['next_token']
for user, tweet in zip(tweets.includes['users'],tweets.data):
    tweet_json = {}
    tweet_json['tweet']= tweet.data
    tweet_json['user'] = user.data
    try:
        tweet_collection.insert_one(tweet_json)
        print(tweet_json['tweet']['created_at'])
    except:
        pass
# Out:
# 2025-10-29T18:13:50.000Z
# 2025-10-29T18:13:50.000Z
# 2025-10-29T18:13:49.000Z
# 2025-10-29T18:13:49.000Z
# 2025-10-29T18:13:49.000Z
# 2025-10-29T18:13:49.000Z
# 2025-10-29T18:13:48.000Z
# 2025-10-29T18:13:48.000Z
# 2025-10-29T18:13:48.000Z
# 2025-10-29T18:13:47.000Z
# 2025-10-29T18:13:28.000Z
# 2025-10-29T18:13:27.000Z
# 2025-10-29T18:13:27.000Z
# 2025-10-29T18:13:27.000Z

# %% [markdown]
# Continue fetching early tweets with the same query. YOU WILL REACH YOUR RATE LIMIT VERY FAST!

# %%
for i in range(5): # change the number here to fetch more tweets
    tweets = tweet_client.search_recent_tweets(query=query, max_results=100,
                                        expansions=['author_id'], 
                                        tweet_fields = ['created_at','entities','lang','public_metrics','geo'],
                                        user_fields = ['id', 'location','name', 'public_metrics','username'],
                                        next_token=next_token)
    next_token = tweets.meta['next_token']
    for user, tweet in zip(tweets.includes['users'],tweets.data):
        tweet_json = {}
        tweet_json['tweet']= tweet.data
        tweet_json['user'] = user.data
        try:
            tweet_collection.insert_one(tweet_json)
            print(tweet_json['tweet']['created_at'])
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/envs/python3/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 for i in range(5): # change the number here to fetch more tweets
# ----> 2     tweets = tweet_client.search_recent_tweets(query=query, max_results=100,
#       3                                         expansions=['author_id'],
#       4                                         tweet_fields = ['created_at','entities','lang','public_metrics','geo'],
#       5                                         user_fields = ['id', 'location','name', 'public_metrics','username'],
#       6                                         next_token=next_token)
#       7     next_token = tweets.meta['next_token']
#       8     for user, tweet in zip(tweets.includes['users'],tweets.data):
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/tweepy/client.py:1276, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1184 """search_recent_tweets( \
#    1185     query, *, end_time=None, expansions=None, max_results=None, \
#    1186     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1273 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1274 """
#    1275 params["query"] = query
# -> 1276 return self._make_request(
#    1277     "GET", "/2/tweets/search/recent", params=params,
#    1278     endpoint_parameters=(
#    1279         "end_time", "expansions", "max_results", "media.fields",
#    1280         "next_token", "place.fields", "poll.fields", "query",
#    1281         "since_id", "sort_order", "start_time", "tweet.fields",
#    1282         "until_id", "user.fields"
#    1283     ), data_type=Tweet, user_auth=user_auth
#    1284 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/tweepy/client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/tweepy/client.py:84, in BaseClient.request(self, method, route, params, json, user_auth)
#      75     headers["Authorization"] = f"Bearer {self.bearer_token}"
#      77 log.debug(
#      78     f"Making API request: {method} {host + route}\n"
#      79     f"Parameters: {params}\n"
#      80     f"Headers: {headers}\n"
#      81     f"Body: {json}"
#      82 )
# ---> 84 with self.session.request(
#      85     method, host + route, params=params, json=json, headers=headers,
#      86     auth=auth
#      87 ) as response:
#      88     log.debug(
#      89         "Received API response: "
#      90         f"{response.status_code} {response.reason}\n"
#      91         f"Headers: {response.headers}\n"
#      92         f"Content: {response.content}"
#      93     )
#      95     if response.status_code == 400:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/requests/adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#    (...)
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#     662     if isinstance(e.reason, ConnectTimeoutError):
#     663         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ## Close Database Connection

# %%
mongo_client.close()
